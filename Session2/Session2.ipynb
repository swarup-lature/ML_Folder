# %%
# Session1

# %%
# Simple Example

# %%
import numpy as np
import pandas as pd

# %%
X=np.array([1,2,3,4])
slope=0.5
intercept=4

# %%
Y=slope*X+intercept

# %%
Y
# Out:
# array([4.5, 5. , 5.5, 6. ])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X,Y)
plt.plot(X,Y)

# %%
# steps of ml
# 1)Data ingestion(reading a csv file)
# 2)Data cleaning
# 3)EDA
# 4)feature selection
# 5)Model Training
# 6)Testing on unknown data

# %%
df=pd.read_csv("placement.csv")

# %%
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
df.shape
# Out:
# (200, 2)

# %%
df.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
plt.scatter(df['cgpa'],df['package'])

# %%
# seperate data in input feature and output feature

# %%
X=df[['cgpa']] #input feature or independent feature
Y=df['package'] #output feature or dependent feature or Target value

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# train-test split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.30,random_state=42)

# %%
model=LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# np.float64(-0.980883767663578)

# %%
model.coef_
# Out:
# array([0.57018094])
